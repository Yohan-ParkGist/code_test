# %%
while 1:
    try:
        a, b, c = map(int, input().split())

        arr = sorted([a, b, c])
        if(arr[2]>=arr[1]+arr[0]):
            print(2*(arr[1]+arr[0])-1)
        else:
            print(a+b+c)
            
    except Exception:
        break
